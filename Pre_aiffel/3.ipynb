# %% [markdown]
# 각자 다른 마법사 20명 랜덤으로 생성 dtype(name: str, age: int, sex: str, dormitory: str)
#
# 이름 (랜덤)
# 나이 (10 ~ 30살 랜덤)
# 성별 (여자 남자 랜덤)
# 기숙사 (4가지 중 랜덤)
#
# 각자 서로 랜덤한 행동 10번을 취함 (점수 얻기, 점수 잃기, 아무것도 하지 않기)
#
# 행동 종료 후 각 기숙사의 점수 출력 후 프로그램 종료

# %%
import random
import names


class Dormitory:
    point = 0
    name = ''

    def __init__(self, name):
        self.name = name

    def get_name(self):
        return self.name

    def get_point(self):
        self.point += 1

    def lose_point(self):
        self.point -= 1

    def print_point(self):
        print(f'{self.name}의 점수는 {self.point}점!')


class person:
    def __init__(self, name, age, sex):
        self.name = name
        self.age = age
        self.sex = sex

    def introduce(self):
        print(f'{self.name}는 {self.age}세 {self.sex}!')


class wizard(person):
    def __init__(self, name, age, sex, dormitory):
        super().__init__(name, age, sex)
        self.dormitory = dormitory

    def introduce(self):
        print(f'{self.name}는 {self.age}세 {self.sex} {self.dormitory.get_name()}!')

    def action(self, action):
        if action == 0:
            self.dormitory.get_point()
        elif action == 1:
            self.dormitory.lose_point()
        else:
            pass


dormitorys = [Dormitory('그리핀도르'), Dormitory(
    '슬리데린'), Dormitory('래번클로'), Dormitory('후플푸프')]
wizards = []

# 20명 랜덤 생성
for _ in range(20):
    name = names.get_full_name()
    age = random.randint(10, 30)
    sex = random.randint(0, 1)
    if sex == 0:
        sex = '남자'
    else:
        sex = '여자'
    dormitory = random.randint(0, 3)

    wizards.append(wizard(name, age, sex, dormitorys[dormitory]))

# 20명 소개
for magicion in wizards:
    magicion.introduce()

# 20명이 각자 랜덤한 행동 10번을 취함
for magicion in wizards:
    for i in range(10):
        action = random.randint(0, 2)
        magicion.action(action)

# 기숙사의 최종 점수 출력
for dormitory in dormitorys:
    dormitory.print_point()
    print(f'{dormitory.get_name()} 기숙사에 소속된 사람은 : ', end='')
    for magicion in wizards:
        if magicion.dormitory.get_name() == dormitory.get_name():
            print(f'[{magicion.name} {magicion.age}세{magicion.sex}] ', end='')
    print()
# Out:
# August Cassady는 16세 여자 슬리데린!
# Jennifer Cross는 21세 여자 래번클로!
# Ryan Schroeder는 23세 남자 후플푸프!
# Pauline Brooks는 15세 여자 래번클로!
# Jacqueline Gabbard는 13세 여자 슬리데린!
# Edwin Little는 16세 여자 슬리데린!
# Monica Davila는 28세 남자 슬리데린!
# Carmen Carter는 25세 남자 그리핀도르!
# Stephen Evans는 27세 남자 슬리데린!
# Melanie Rodgers는 21세 남자 후플푸프!
# Isiah Ghent는 14세 남자 그리핀도르!
# Courtney Moss는 10세 남자 그리핀도르!
# Daniel Pancoast는 13세 여자 슬리데린!
# William Duncan는 20세 여자 후플푸프!
# Edward Rodriguez는 14세 남자 슬리데린!
# Jeff Bell는 21세 여자 그리핀도르!
# Sherri Parm는 13세 남자 후플푸프!
# Margaret Griffith는 21세 남자 슬리데린!
# David Jones는 23세 남자 래번클로!
# Tommie Glover는 16세 여자 그리핀도르!
# 그리핀도르의 점수는 1점!
# 그리핀도르 기숙사에 소속된 사람은 : [Carmen Carter 25세남자] [Isiah Ghent 14세남자] [Courtney Moss 10세남자] [Jeff Bell 21세여자] [Tommie Glover 16세여자]
# 슬리데린의 점수는 4점!
# 슬리데린 기숙사에 소속된 사람은 : [August Cassady 16세여자] [Jacqueline Gabbard 13세여자] [Edwin Little 16세여자] [Monica Davila 28세남자] [Stephen Evans 27세남자] [Daniel Pancoast 13세여자] [Edward Rodriguez 14세남자] [Margaret Griffith 21세남자]
# 래번클로의 점수는 -6점!
# 래번클로 기숙사에 소속된 사람은 : [Jennifer Cross 21세여자] [Pauline Brooks 15세여자] [David Jones 23세남자]
# 후플푸프의 점수는 2점!
# 후플푸프 기숙사에 소속된 사람은 : [Ryan Schroeder 23세남자] [Melanie Rodgers 21세남자] [William Duncan 20세여자] [Sherri Parm 13세남자]

# %% [markdown]
# → 쓰레드를 활용하면 20명이 각자 랜덤한 행동 10번 하는 것을 더 최적화 시킬 수 있음.
